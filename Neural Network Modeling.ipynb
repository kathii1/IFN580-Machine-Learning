# %%
import pandas as pd
import numpy as np
from data_preparation import data_prep
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load the preprocessed data
df = data_prep()
df.info
# Out:
# C:\Users\49157\OneDrive\Dokumente\QUT (TUM Semester 5)\IFN580 Machine Learning\Assessment 1\Machine-Learning-Assignment-1\data_preparation.py:5: DtypeWarning: Columns (27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('kick.csv')
# Auction                              0
# VehYear                              0
# Make                                 0
# Color                                0
# Transmission                         0
# WheelType                            0
# VehOdo                               0
# Size                                 0
# MMRAcquisitionAuctionAveragePrice    0
# MMRAcquisitionAuctionCleanPrice      0
# MMRAcquisitionRetailAveragePrice     0
# MMRAcquisitionRetailCleanPrice       0
# MMRCurrentAuctionAveragePrice        0
# MMRCurrentAuctionCleanPrice          0
# MMRCurrentRetailAveragePrice         0
# MMRCurrentRetailCleanPrice           0
# PRIMEUNIT                            0
# AUCGUART                             0
# VNST                                 0
# VehBCost                             0
# IsOnlineSale                         0
# WarrantyCost                         0
# IsBadBuy                             0
# PurchaseMonth                        0
# PurchaseYear                         0
# dtype: int64
# <bound method DataFrame.info of         VehOdo  MMRAcquisitionAuctionAveragePrice  \
# 0      51099.0                             8566.0
# 1      48542.0                             8566.0
# 2      46318.0                             8835.0
# 3      50413.0                             7165.0
# 4      50199.0                             8566.0
# ...        ...                                ...
# 41471  45234.0                             1996.0
# 41472  71759.0                             6418.0
# 41473  88500.0                             8545.0
# 41474  79554.0                             6420.0
# 41475  66855.0                             7535.0
#
#        MMRAcquisitionAuctionCleanPrice  MMRAcquisitionRetailAveragePrice  \
# 0                               9325.0                            9751.0
# 1                               9325.0                            9751.0
# 2                               9428.0                           10042.0
# 3                               7770.0                            8238.0
# 4                               9325.0                            9751.0
# ...                                ...                               ...
# 41471                           2993.0                            2656.0
# 41472                           7325.0                            7431.0
# 41473                           9959.0                            9729.0
# 41474                           7604.0                            7434.0
# 41475                           8771.0                            8638.0
#
#        MMRAcquisitionRetailCleanPrice  MMRCurrentAuctionAveragePrice  \
# 0                             10571.0                         7781.0
# 1                             10571.0                         8568.0
# 2                             10682.0                         8137.0
# 3                              8892.0                         7074.0
# 4                             10571.0                         7857.0
# ...                               ...                            ...
# 41471                          3732.0                         2190.0
# 41472                          8411.0                         6785.0
# 41473                         11256.0                         8375.0
# 41474                          8712.0                         6590.0
# 41475                          9973.0                         7730.0
#
#        MMRCurrentAuctionCleanPrice  MMRCurrentRetailAveragePrice  \
# 0                           8545.0                       11777.0
# 1                           9325.0                        9753.0
# 2                           8733.0                        9288.0
# 3                           7629.0                        8140.0
# 4                           8711.0                        8986.0
# ...                            ...                           ...
# 41471                       3055.0                        4836.0
# 41472                       8132.0                       10151.0
# 41473                       9802.0                       11831.0
# 41474                       7684.0                       10099.0
# 41475                       9102.0                       11954.0
#
#        MMRCurrentRetailCleanPrice  VehBCost  ...  PurchaseMonth_5  \
# 0                         12505.0    7800.0  ...            False
# 1                         10571.0    7800.0  ...            False
# 2                          9932.0    7800.0  ...            False
# 3                          8739.0    6000.0  ...            False
# 4                          9908.0    7800.0  ...            False
# ...                           ...       ...  ...              ...
# 41471                      5937.0    4200.0  ...            False
# 41472                     11652.0    6200.0  ...            False
# 41473                     14402.0    8200.0  ...            False
# 41474                     11228.0    7000.0  ...            False
# 41475                     13246.0    8000.0  ...            False
#
#        PurchaseMonth_6  PurchaseMonth_7  PurchaseMonth_8  PurchaseMonth_9  \
# 0                False            False            False             True
# 1                False            False            False             True
# 2                False            False            False             True
# 3                False            False            False             True
# 4                False            False            False             True
# ...                ...              ...              ...              ...
# 41471            False            False            False            False
# 41472            False            False            False            False
# 41473            False            False            False            False
# 41474            False            False            False            False
# 41475            False            False            False            False
#
#        PurchaseMonth_10  PurchaseMonth_11  PurchaseMonth_12  \
# 0                 False             False             False
# 1                 False             False             False
# 2                 False             False             False
# 3                 False             False             False
# 4                 False             False             False
# ...                 ...               ...               ...
# 41471             False             False              True
# 41472             False             False              True
# 41473             False             False              True
# 41474             False             False              True
# 41475             False             False              True
#
#        PurchaseYear_2009  PurchaseYear_2010
# 0                   True              False
# 1                   True              False
# 2                   True              False
# 3                   True              False
# 4                   True              False
# ...                  ...                ...
# 41471               True              False
# 41472               True              False
# 41473               True              False
# 41474               True              False
# 41475               True              False
#
# [41476 rows x 145 columns]>
